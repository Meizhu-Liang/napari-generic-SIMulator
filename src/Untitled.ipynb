# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
L = 5
dL = 0.05
numFil = 10

# %%
fig = plt.figure(figsize=(12,12))
axs = plt.axes(projection='3d')
for i in range(numFil):
    alpha = 2 * np.pi * np.random.rand()
    beta = np.pi / 4 * (1 - 2 * np.random.rand())
    
    xS = -L/2 + L * np.random.rand(1,1) 
    yS = -L/2 + L * np.random.rand(1,1)
    zS = 0

    x1 = xS + (L * np.cos(alpha) * np.cos(beta))
    y1 = yS + (L * np.sin(alpha) * np.cos(beta))
    z1 = zS + (L * np.sin(beta))

    x2 = xS - (L * np.cos(alpha) * np.cos(beta))
    y2 = yS - (L * np.sin(alpha) * np.cos(beta))
    z2 = zS - (L * np.sin(beta))

    px = 2 * np.pi * np.random.rand()
    fx = 2 * np.pi * 0.5 * np.random.rand()
    ax = L / 3 * np.random.rand()
    py = 2 * np.pi * np.random.rand()
    fy = 2 * np.pi * 1.0 * np.random.rand()
    ay = L / 5 * np.random.rand()
    pz = 2 * np.pi * np.random.rand()
    fz = 2 * np.pi * 1.0 * np.random.rand()
    az = L / 5 * np.random.rand()

    l = np.arange(0, 1, dL / L)
    x = x1 + (x2 - x1) * l + ax * np.cos(fx * l + px)
    y = y1 + (y2 - y1) * l + ay * np.cos(fy * l + py)
    z = z1 + (z2 - z1) * l + az * np.cos(fz * l + pz)

    axs.scatter(x, y, z)

# %%
np.random.rand(1,1)
# Out:
# array([[0.20529464]])

# %%
np.dstack((x,y,z)).squeeze()
# Out:
# array([[-2.77947065e+00,  2.54217374e+00,  1.33329188e+00],
#        [-2.73530498e+00,  2.45522408e+00,  1.30774876e+00],
#        [-2.69074148e+00,  2.36827536e+00,  1.28220040e+00],
#        [-2.64578246e+00,  2.28132754e+00,  1.25664686e+00],
#        [-2.60043053e+00,  2.19438058e+00,  1.23108823e+00],
#        [-2.55468867e+00,  2.10743445e+00,  1.20552455e+00],
#        [-2.50856013e+00,  2.02048909e+00,  1.17995589e+00],
#        [-2.46204852e+00,  1.93354447e+00,  1.15438232e+00],
#        [-2.41515773e+00,  1.84660055e+00,  1.12880390e+00],
#        [-2.36789198e+00,  1.75965729e+00,  1.10322070e+00],
#        [-2.32025579e+00,  1.67271465e+00,  1.07763277e+00],
#        [-2.27225398e+00,  1.58577259e+00,  1.05204020e+00],
#        [-2.22389167e+00,  1.49883107e+00,  1.02644304e+00],
#        [-2.17517429e+00,  1.41189004e+00,  1.00084136e+00],
#        [-2.12610753e+00,  1.32494948e+00,  9.75235219e-01],
#        [-2.07669741e+00,  1.23800933e+00,  9.49624691e-01],
#        [-2.02695018e+00,  1.15106955e+00,  9.24009839e-01],
#        [-1.97687241e+00,  1.06413011e+00,  8.98390730e-01],
#        [-1.92647091e+00,  9.77190965e-01,  8.72767430e-01],
#        [-1.87575278e+00,  8.90252075e-01,  8.47140006e-01],
#        [-1.82472535e+00,  8.03313399e-01,  8.21508525e-01],
#        [-1.77339623e+00,  7.16374896e-01,  7.95873053e-01],
#        [-1.72177326e+00,  6.29436526e-01,  7.70233659e-01],
#        [-1.66986454e+00,  5.42498247e-01,  7.44590408e-01],
#        [-1.61767838e+00,  4.55560021e-01,  7.18943369e-01],
#        [-1.56522332e+00,  3.68621805e-01,  6.93292609e-01],
#        [ 1.11818609e+00, -3.89217807e+00, -5.66714574e-01],
#        [ 1.17058234e+00, -3.97916696e+00, -5.92462843e-01],
#        [ 1.22270780e+00, -4.06615787e+00, -6.18211260e-01],
#        [ 1.27455395e+00, -4.15315083e+00, -6.43959752e-01],
#        [ 1.32611253e+00, -4.24014588e+00, -6.69708248e-01],
#        [ 1.37737550e+00, -4.32714305e+00, -6.95456677e-01],
#        [ 1.42833508e+00, -4.41414239e+00, -7.21204967e-01],
#        [ 1.47898372e+00, -4.50114393e+00, -7.46953047e-01],
#        [ 1.52931413e+00, -4.58814771e+00, -7.72700846e-01],
#        [ 1.57931928e+00, -4.67515376e+00, -7.98448292e-01],
#        [ 1.62899241e+00, -4.76216213e+00, -8.24195314e-01],
#        [ 1.67832702e+00, -4.84917284e+00, -8.49941841e-01],
#        [ 1.72731691e+00, -4.93618594e+00, -8.75687801e-01],
#        [ 1.77595614e+00, -5.02320147e+00, -9.01433123e-01],
#        [ 1.82423907e+00, -5.11021945e+00, -9.27177736e-01],
#        [ 1.87216035e+00, -5.19723992e+00, -9.52921568e-01],
#        [ 1.91971491e+00, -5.28426293e+00, -9.78664548e-01],
#        [ 1.96689800e+00, -5.37128851e+00, -1.00440661e+00],
#        [ 2.01370517e+00, -5.45831668e+00, -1.03014767e+00],
#        [ 2.06013228e+00, -5.54534750e+00, -1.05588767e+00],
#        [ 2.10617548e+00, -5.63238099e+00, -1.08162653e+00],
#        [ 2.15183126e+00, -5.71941719e+00, -1.10736419e+00],
#        [ 2.19709642e+00, -5.80645614e+00, -1.13310056e+00],
#        [ 2.24196807e+00, -5.89349787e+00, -1.15883559e+00],
#        [ 2.28644365e+00, -5.98054241e+00, -1.18456920e+00],
#        [ 2.33052093e+00, -6.06758980e+00, -1.21030132e+00]])

# %%
y.shape
# Out:
# (1, 100)

# %%
        for i in range(numFil):
            alpha = 2 * np.pi * np.random.rand()
            beta = np.pi / 4 * (1 - 2 * np.random.rand())

            xS = -L / 2 + L * np.random.rand(1, 1)
            yS = -L / 2 + L * np.random.rand(1, 1)
            zS = 0

            x1 = xS + (L * np.cos(alpha) * np.cos(beta))
            y1 = yS + (L * np.sin(alpha) * np.cos(beta))
            z1 = zS + (L * np.sin(beta))

            x2 = xS - (L * np.cos(alpha) * np.cos(beta))
            y2 = yS - (L * np.sin(alpha) * np.cos(beta))
            z2 = zS - (L * np.sin(beta))

            px = 2 * np.pi * np.random.rand()
            fx = 2 * np.pi * 0.5 * np.random.rand()
            ax = L / 3 * np.random.rand()
            py = 2 * np.pi * np.random.rand()
            fy = 2 * np.pi * 1.0 * np.random.rand()
            ay = L / 5 * np.random.rand()
            pz = 2 * np.pi * np.random.rand()
            fz = 2 * np.pi * 1.0 * np.random.rand()
            az = L / 5 * np.random.rand()

            l = np.arange(0, 1, dL / L)
            x = x1 + (x2 - x1) * l + ax * np.cos(fx * l + px)
            y = y1 + (y2 - y1) * l + ay * np.cos(fy * l + py)
            z = z1 + (z2 - z1) * l + az * np.cos(fz * l + pz)

            if i == 0:
                points = np.dstack([x,y,z]).squeeze()
            else:
                points = np.concatenate((points, np.dstack([x,y,z]).squeeze()))
        npoints = points.shape[0]

# %%
npoints
# Out:
# 1000
