# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\ML2618\\PycharmProjects\\napari_generic_SIMulator', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\python38.zip', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\DLLs', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\lib', '', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\lib\\site-packages', 'C:\\Users\\ML2618\\PycharmProjects\\napari-pcd-reader_draft\\src', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\lib\\site-packages\\win32', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\lib\\site-packages\\win32\\lib', 'C:\\Users\\ML2618\\Anaconda3\\envs\\napari-generic-SIMulator\\lib\\site-packages\\Pythonwin']

# %%
import napari
from src.napari_generic_simulator._widget import SIMulator, PointCloud
# Out:
# cupy imported
# torch imported
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
viewer = napari.Viewer()
point_cloud = PointCloud(viewer)
simulator = SIMulator(viewer)
w1 = viewer.window.add_dock_widget(point_cloud, name='pc_Jupyter notebook test', add_vertical_stretch=True)
w2 = viewer.window.add_dock_widget(simulator, name='SIMdata_Jupyter notebook test', add_vertical_stretch=True)
viewer.window._qt_window.tabifyDockWidget(w1, w2)
napari.run()
# Out:
# Point cloud generated

# %%
plt.figure()
plt.plot(simulator.sim.psffile)
plt.title('PSF profile')
plt.xlabel('z')
plt.ylabel('Summed PSF (a.u.)')
plt.show()

# %%
plt.figure()
plt.plot(simulator.sim.aotffile)
plt.title('MTF profile')
plt.xlabel('z')
plt.ylabel('Summed MTF a.u.')
plt.show()
